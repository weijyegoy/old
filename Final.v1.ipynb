# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest

data = pd.read_csv("D:/創新提案/Data/loan_data.csv")
df = data

# %%
print(data.info())

print(data.describe())

print(data.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %%
sns.histplot(df, x='person_age', hue='loan_status')
plt.title("Age Distribution by Loan Approval Status")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
sns.histplot(df, x='loan_amnt', hue='loan_status')
plt.title("Does loan status relate to the loan amount?")
plt.xlabel("Loan Amount")
plt.ylabel("Count")
plt.show()

# %%
gender_approval = df.groupby('person_gender')['loan_status'].mean().reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(x='person_gender', y='loan_status', data=gender_approval)
plt.title('Loan Approval Rate by Gender')
plt.xlabel('Gender')
plt.ylabel('Approval Rate')
plt.show()

# %%
gender_approval
# Out:
#   person_gender  loan_status
# 0        female     0.222481
# 1          male     0.222012

# %%
此資料集為貸款審批的分類資料，資料集包含申請人與其貸款的相關資訊。原始資料為Kaggle上Credit Risk Dataset的
     合成版本，已使用SMOTENC擴大實例數量。

來源：OpenML 資料集 (ID : 46434)
樣本數：45000
特徵數：14（8個數值型，6個類別型）
目標特徵：Loan_Status（貸款批准狀態）

瞭解影響貸款審批的關鍵因素

建立一個貸款審批預測模型

提出改善貸款審批流程的建議

識別潛在的風險群體和機會客戶群
